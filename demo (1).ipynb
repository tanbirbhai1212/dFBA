# %%
#Installing necessary packages and library
from copy import deepcopy

from process_bigraph import Composite
from process_bigraph.composite import ProcessTypes

from cdFBA import register_types
from cdFBA.processes.dfba import DFBA, UpdateEnvironment, Chemostat, Injector, WaveFunction

from cdFBA.utils import make_cdfba_composite, get_injector_spec, get_wave_spec, get_chemo_spec

from matplotlib import pyplot as plt
from pprint import pprint
# Out:
# <unknown>:1: SyntaxWarning: invalid escape sequence '\s'

# %%
#Creating a model dictionary. 
model_dict = {
        'E.coli' : 'iAF1260b',
        'S.flexneri' : 'iSFxv_1172'
    }
#list exchange reactions
exchanges = ['EX_glc__D_e', 'EX_ac_e']
#set environment volume
volume=2
# define a single dFBA model
spec = make_cdfba_composite(model_dict, medium_type=None, exchanges=exchanges, volume=volume, interval=1.0)
#print spec
pprint(spec)
# Out:
# {'E.coli': {'_type': 'process',
#             'address': 'local:DFBA',
#             'config': {'biomass_identifier': 'BIOMASS_Ec_iAF1260_core_59p81M',
#                        'bounds': {},
#                        'kinetics': {'Acetate': (0.5, 2.0),
#                                     'D-Glucose': (0.5, 2.0)},
#                        'model_file': 'iAF1260b',
#                        'name': 'E.coli',
#                        'reaction_map': {'Acetate': 'EX_ac_e',
#                                         'D-Glucose': 'EX_glc__D_e'}},
#             'inputs': {'current_update': ['dFBA Results'],
#                        'shared_environment': ['shared environment']},
#             'interval': 1.0,
#             'outputs': {'dfba_update': ['dFBA Results', 'E.coli']}},
#  'S.flexneri': {'_type': 'process',
#                 'address': 'local:DFBA',
#                 'config': {'biomass_identifier': 'BIOMASS_Ec_iJO1366_core_53p95M',
#                            'bounds': {},
#                            'kinetics': {'Acetate': (0.5, 2.0),
#                                         'D-Glucose': (0.5, 2.0)},
#                            'model_file': 'iSFxv_1172',
#                            'name': 'S.flexneri',
#                            'reaction_map': {'Acetate': 'EX_ac_e',
#                                             'D-Glucose': 'EX_glc__D_e'}},
#                 'inputs': {'current_update': ['dFBA Results'],
#                            'shared_environment': ['shared environment']},
#                 'interval': 1.0,
#                 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}},
#  'dFBA Results': {'E.coli': {'Acetate': 0, 'D-Glucose': 0, 'E.coli': 0},
#                   'S.flexneri': {'Acetate': 0,
#                                  'D-Glucose': 0,
#                                  'S.flexneri': 0}},
#  'shared environment': {'concentrations': {'Acetate': 10.0,
#                                            'D-Glucose': 10.0,
#                                            'E.coli': 0.25,
#                                            'S.flexneri': 0.25},
#                         'counts': {'Acetate': 20,
#                                    'D-Glucose': 20,
#                                    'E.coli': 0.5,
#                                    'S.flexneri': 0.5},
#                         'volume': 2},
#  'update environment': {'_type': 'process',
#                         'address': 'local:UpdateEnvironment',
#                         'config': {},
#                         'inputs': {'shared_environment': ['shared environment'],
#                                    'species_updates': ['dFBA Results']},
#                         'outputs': {'shared_environment': ['shared '
#                                                            'environment']}}}

# %%
#Set reaction bounds
spec['E.coli']['config']['bounds'] = {
            "EX_o2_e": {"lower": -2, "upper": None},
            "ATPM": {"lower": 1, "upper": 1}
        }
spec['S.flexneri']['config']['bounds'] = {
            "EX_o2_e": {"lower": -2, "upper": None},
            "ATPM": {"lower": 1, "upper": 1}
        }

# %%
#set initial concentrations
spec['shared environment']['counts']['Acetate'] = 0
spec['shared environment']['concentrations']['Acetate'] = 0/volume
spec['shared environment']['counts']['D-Glucose'] = 80
spec['shared environment']['concentrations']['D-Glucose'] = 80/volume

# %%
#set kinetics
spec['E.coli']['config']['kinetics']['D-Glucose'] = (0.02, 15)
spec['S.flexneri']['config']['kinetics']['D-Glucose'] = (0.02, 15)
spec['E.coli']['config']['kinetics']['Acetate'] = (0.5, 7)
spec['S.flexneri']['config']['kinetics']['Acetate'] = (0.5, 7)

# %% [markdown]
# # Register Data Types and Processes
# Here we register cdFBA related data-types and processes to the `core` object so that the model composite can access them. A `core` object is instantiated using the `ProcessType()` function. Data types are defined in the `init.py` file, and the `register_types()` function registers them to the `core` object. Process registration is done using the `core.register_process()` function.

# %%
#create the core object
core = ProcessTypes()
#register data types
core = register_types(core)
#register all processes and steps
core.register_process('DFBA', DFBA)
core.register_process('UpdateEnvironment', UpdateEnvironment)
core.register_process('Chemostat', Chemostat)
core.register_process('WaveFunction', WaveFunction)
core.register_process('Injector', Injector)

# %% [markdown]
# ### Create Simulation Composite
# The `Composite` class creates the simulation object using the spec created earlier.

# %%
#creating simulation composite
sim = Composite({
        "state": spec,
        "emitter": {'mode': 'all'}},
        core=core
    )
# Out:
# Warning: read_emitter_config() is deprecated and will be removed in a future version. Use use Vivarium for managing simulations and emitters instead of Composite.

# %%
#runing simulation
sim.run(40)

# %%
#gathering results
results = sim.gather_results()[('emitter',)]

# %%
#extracting time-series data
timepoints = []
for timepoint in results:
    time = timepoint.pop('global_time')
    timepoints.append(time)
    dfba_spec = timepoint.pop(list(model_dict.keys())[0])
    print(f'TIME: {time}')
    pprint(f'STATE: {timepoint}')
    env = [timepoint['shared environment']['concentrations'] for timepoint in results]
env_combined = {}
for d in env:
    for key, value in d.items():
        if key not in env_combined:
            env_combined[key] = []
        env_combined[key].append(value)
# Out:
# TIME: 0.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': 0, 'Acetate': 0, 'E.coli': "
#  "0}, 'S.flexneri': {'D-Glucose': 0, 'Acetate': 0, 'S.flexneri': 0}}, 'shared "
#  "environment': {'concentrations': {'D-Glucose': 40.0, 'Acetate': 0.0, "
#  "'E.coli': 0.25, 'S.flexneri': 0.25}, 'counts': {'D-Glucose': 80, 'Acetate': "
#  "0, 'E.coli': 0.5, 'S.flexneri': 0.5}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x126489350>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x1314e9950>}}')
# TIME: 1.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-7.496251874062968), 'Acetate': np.float64(6.726974615480175), "
#  "'E.coli': np.float64(0.24067371258486692)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-7.496251874062968), 'Acetate': np.float64(6.708871791798614), "
#  "'S.flexneri': np.float64(0.24111451919722585)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': 80, 'Acetate': 0, 'E.coli': 0.5, 'S.flexneri': "
#  "0.5}, 'concentrations': {'D-Glucose': 40.0, 'Acetate': 0.0, 'E.coli': 0.25, "
#  "'S.flexneri': 0.25}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x16ba50950>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x16c814410>}}')
# TIME: 2.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-11.10397967186553), 'Acetate': np.float64(9.96452735879333), "
#  "'E.coli': np.float64(0.3565057991246457)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-11.11058812519618), 'Acetate': np.float64(9.943628496617135), "
#  "'S.flexneri': np.float64(0.35737102479671384)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(72.50374812593704), 'Acetate': "
#  "np.float64(6.708871791798614), 'E.coli': np.float64(0.7406737125848669), "
#  "'S.flexneri': np.float64(0.7411145191972258)}, 'concentrations': "
#  "{'D-Glucose': np.float64(36.25187406296852), 'Acetate': "
#  "np.float64(3.354435895899307), 'E.coli': np.float64(0.37033685629243346), "
#  "'S.flexneri': np.float64(0.3705572595986129)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x163a4b130>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x163a26b10>}}')
# TIME: 3.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-16.44697683899978), 'Acetate': np.float64(14.759403806393399), "
#  "'E.coli': np.float64(0.5280568635546699)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-16.466554567624595), 'Acetate': np.float64(14.73721590873124), "
#  "'S.flexneri': np.float64(0.529652476399599)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(61.393160000740856), 'Acetate': "
#  "np.float64(16.652500288415748), 'E.coli': np.float64(1.0971795117095127), "
#  "'S.flexneri': np.float64(1.0984855439939396)}, 'concentrations': "
#  "{'D-Glucose': np.float64(30.696580000370428), 'Acetate': "
#  "np.float64(8.326250144207874), 'E.coli': np.float64(0.5485897558547563), "
#  "'S.flexneri': np.float64(0.5492427719969698)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x166643e50>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x163a26ea0>}}')
# TIME: 4.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-24.356869155062906), 'Acetate': np.float64(21.858250153530438), "
#  "'E.coli': np.float64(0.7820454647497329)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-24.400355131518896), 'Acetate': np.float64(21.83838291775036), "
#  "'S.flexneri': np.float64(0.78487174853712)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(44.946183161741075), 'Acetate': "
#  "np.float64(31.411904094809145), 'E.coli': np.float64(1.6252363752641825), "
#  "'S.flexneri': np.float64(1.6281380203935387)}, 'concentrations': "
#  "{'D-Glucose': np.float64(22.473091580870538), 'Acetate': "
#  "np.float64(15.705952047404573), 'E.coli': np.float64(0.8126181876320913), "
#  "'S.flexneri': np.float64(0.8140690101967694)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x163af0320>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x17cc7ed50>}}')
# TIME: 5.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-36.039064325654614), 'Acetate': np.float64(32.34573762846799), "
#  "'E.coli': np.float64(1.1573231687776466)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-36.12481631167138), 'Acetate': np.float64(32.33564212306039), "
#  "'S.flexneri': np.float64(1.1621749138648356)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(20.54582803022218), 'Acetate': "
#  "np.float64(53.250287012559504), 'E.coli': np.float64(2.4072818400139155), "
#  "'S.flexneri': np.float64(2.413009768930659)}, 'concentrations': "
#  "{'D-Glucose': np.float64(10.27291401511109), 'Acetate': "
#  "np.float64(26.625143506279752), 'E.coli': np.float64(1.2036409200069578), "
#  "'S.flexneri': np.float64(1.2065048844653294)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x17dab11d0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x163a4b460>}}')
# TIME: 6.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.0445212483846325), 'E.coli': np.float64(0.16156965164154444)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-5.961504488588635), 'S.flexneri': "
#  "np.float64(0.11058342587433857)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(85.58592913561989), "
#  "'E.coli': np.float64(3.5646050087915624), 'S.flexneri': "
#  "np.float64(3.5751846827954945)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(42.792964567809946), 'E.coli': "
#  "np.float64(1.7823025043957812), 'S.flexneri': "
#  "np.float64(1.7875923413977473)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x1634ae810>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x163a4b240>}}')
# TIME: 7.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.363821939843031), 'E.coli': np.float64(0.16889297421648217)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.1458987641775105), 'S.flexneri': "
#  "np.float64(0.11400386290413396)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(79.62442464703126), "
#  "'E.coli': np.float64(3.7261746604331067), 'S.flexneri': "
#  "np.float64(3.685768108669833)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(39.81221232351563), 'E.coli': "
#  "np.float64(1.8630873302165534), 'S.flexneri': "
#  "np.float64(1.8428840543349165)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3021852e0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x300999b50>}}')
# TIME: 8.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.697595287138596), 'E.coli': np.float64(0.1765482344603414)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.335996507572127), 'S.flexneri': "
#  "np.float64(0.11753009688681254)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(73.47852588285375), "
#  "'E.coli': np.float64(3.895067634649589), 'S.flexneri': "
#  "np.float64(3.799771971573967)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(36.73926294142687), 'E.coli': "
#  "np.float64(1.9475338173247945), 'S.flexneri': "
#  "np.float64(1.8998859857869834)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3048c8870>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x30099b150>}}')
# TIME: 9.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.046497279351838), 'E.coli': np.float64(0.18455047781390715)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.531974131750716), 'S.flexneri': "
#  "np.float64(0.12116540020963318)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(65.78093059571515), "
#  "'E.coli': np.float64(4.07161586910993), 'S.flexneri': "
#  "np.float64(3.9173020684607796)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(32.890465297857574), 'E.coli': "
#  "np.float64(2.035807934554965), 'S.flexneri': "
#  "np.float64(1.9586510342303898)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x161a9da30>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x161a994f0>}}')
# TIME: 10.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.41121363899146), 'E.coli': np.float64(0.19291543166914074)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.734013506300029), 'S.flexneri': "
#  "np.float64(0.12491314647769904)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(57.73443331636331), "
#  "'E.coli': np.float64(4.2561663469238376), 'S.flexneri': "
#  "np.float64(4.0384674686704125)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(28.867216658181654), 'E.coli': "
#  "np.float64(2.1280831734619188), 'S.flexneri': "
#  "np.float64(2.0192337343352063)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x309744fd0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x161a99130>}}')
# TIME: 11.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.792461169694807), 'E.coli': np.float64(0.20165953627938213)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.942302126183897), 'S.flexneri': "
#  "np.float64(0.1287768136445157)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(49.323219677371846), "
#  "'E.coli': np.float64(4.449081778592978), 'S.flexneri': "
#  "np.float64(4.163380615148111)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(24.661609838685923), 'E.coli': "
#  "np.float64(2.224540889296489), 'S.flexneri': "
#  "np.float64(2.0816903075740556)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x17e9884b0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x30df6db70>}}')
# TIME: 12.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-9.190989165014297), 'E.coli': np.float64(0.21079997707057752)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.1570332857408046), 'S.flexneri': "
#  "np.float64(0.1327599872395737)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(40.530758507677035), "
#  "'E.coli': np.float64(4.65074131487236), 'S.flexneri': "
#  "np.float64(4.292157428792627)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(20.265379253838518), 'E.coli': "
#  "np.float64(2.32537065743618), 'S.flexneri': np.float64(2.1460787143963134)}, "
#  "'volume': 2}, 'S.flexneri': {'inputs': {'shared_environment': ['shared "
#  "environment'], 'current_update': ['dFBA Results']}, 'outputs': "
#  "{'dfba_update': ['dFBA Results', 'S.flexneri']}, 'interval': 1.0, 'address': "
#  "'local:DFBA', 'config': {'model_file': 'iSFxv_1172', 'name': 'S.flexneri', "
#  "'kinetics': {'D-Glucose': (0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': "
#  "{'D-Glucose': 'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x16c525430>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3106b6dd0>}}')
# TIME: 13.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-9.607580881058627), 'E.coli': np.float64(0.22035471841704943)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.378406258063358), 'S.flexneri': "
#  "np.float64(0.13686636369576294)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(31.339769342662738), "
#  "'E.coli': np.float64(4.861541291942938), 'S.flexneri': "
#  "np.float64(4.4249174160322005)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(15.669884671331369), 'E.coli': "
#  "np.float64(2.430770645971469), 'S.flexneri': "
#  "np.float64(2.2124587080161002)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x16c525f70>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x31244a8f0>}}')
# TIME: 14.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-10.043055075883085), 'E.coli': np.float64(0.2303425389481904)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.606626479926104), 'S.flexneri': "
#  "np.float64(0.1410997537797067)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(23.96136308459938), "
#  "'E.coli': np.float64(5.081896010359988), 'S.flexneri': "
#  "np.float64(4.561783779727963)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(11.98068154229969), 'E.coli': "
#  "np.float64(2.540948005179994), 'S.flexneri': "
#  "np.float64(2.2808918898639816)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x16c5269f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x31457dfd0>}}')
# TIME: 15.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-10.49826761865441), 'E.coli': np.float64(0.2407830684554717)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.841905742433318), 'S.flexneri': "
#  "np.float64(0.14546408612819894)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(13.918308008716295), "
#  "'E.coli': np.float64(5.312238549308178), 'S.flexneri': "
#  "np.float64(4.70288353350767)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(6.9591540043581475), 'E.coli': "
#  "np.float64(2.656119274654089), 'S.flexneri': np.float64(2.351441766753835)}, "
#  "'volume': 2}, 'S.flexneri': {'inputs': {'shared_environment': ['shared "
#  "environment'], 'current_update': ['dFBA Results']}, 'outputs': "
#  "{'dfba_update': ['dFBA Results', 'S.flexneri']}, 'interval': 1.0, 'address': "
#  "'local:DFBA', 'config': {'model_file': 'iSFxv_1172', 'name': 'S.flexneri', "
#  "'kinetics': {'D-Glucose': (0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': "
#  "{'D-Glucose': 'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x16c527950>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x31694ec90>}}')
# TIME: 16.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-10.974113171752837), 'E.coli': np.float64(0.251696826472303)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.0844623875637), 'S.flexneri': "
#  "np.float64(0.14996341089402615)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(3.420040390061885), "
#  "'E.coli': np.float64(5.55302161776365), 'S.flexneri': "
#  "np.float64(4.848347619635869)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(1.7100201950309426), 'E.coli': "
#  "np.float64(2.776510808881825), 'S.flexneri': "
#  "np.float64(2.4241738098179346)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x1774306b0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x31a1d6ba0>}}')
# TIME: 17.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x177433b90>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x31d9554f0>}}')
# TIME: 18.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3038385f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x32008a990>}}')
# TIME: 19.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3038397f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x322fc2df0>}}')
# TIME: 20.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x30383a630>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3011850a0>}}')
# TIME: 21.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x30383b470>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x328656550>}}')
# TIME: 22.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x30fbec2f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x32b593050>}}')
# TIME: 23.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x30fbed130>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x32dcc8b40>}}')
# TIME: 24.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x30fbedf70>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x330badfd0>}}')
# TIME: 25.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x30fbeeff0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x32dca23f0>}}')
# TIME: 26.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x30fbefef0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x32dca3290>}}')
# TIME: 27.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x31a1c8d10>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x339cfc170>}}')
# TIME: 28.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
# ...
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x31a1cbb90>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x339cffbf0>}}')
# TIME: 32.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x322ebca10>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x347564ad0>}}')
# TIME: 33.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x322ebd850>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x347565970>}}')
# TIME: 34.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x322ebe6f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x347566810>}}')
# TIME: 35.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x322ebf8f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3475676b0>}}')
# TIME: 36.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x32dca1f10>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x352aec590>}}')
# TIME: 37.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x32dca2e10>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x352aed430>}}')
# TIME: 38.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x32dca3cb0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x352aee2d0>}}')
# TIME: 39.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x339cfcb90>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x352aef170>}}')
# TIME: 40.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9287549510777472), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.1760731836540843), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(5.804718444235953), 'S.flexneri': np.float64(4.998311030529895)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(2.9023592221179766), 'S.flexneri': "
#  "np.float64(2.4991555152649476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x339cfda30>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x35e340050>}}')

# %%
#extract time-series for the shared environment
env = [timepoint['shared environment']['concentrations'] for timepoint in results]
env_combined = {}
for d in env:
    for key, value in d.items():
        if key not in env_combined:
            env_combined[key] = []
        env_combined[key].append(value)

# %%
#plot results for biomass
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key not in ['D-Glucose', 'Acetate']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#plote substrates
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key in ['D-Glucose', 'Acetate']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Environmental Controls
#
# cdFBA includes additional processes to exert control over concentrations of substrates within the shared environment. In the next section we will be demonstrating each of the three processes: `Chemostat`, `WaveFunction`, and `Injector`.

# %% [markdown]
# ### Chemostat
# The `Chemostat` process holds the concentration of a substrate constant to simulate the effects of a chemostat. To demonstrate this, we hold the glucose concentration constant. We must first generate a config dictionary and subsequently add the process specifications to our origina `spec` created above.

# %%
chemostat_config = {
    "substrate_concentrations": {
        "D-Glucose": 40
    }
}
spec2 = deepcopy(spec)
spec2['Chemostat'] = get_chemo_spec(chemostat_config)

# %%
sim2 = Composite({
        "state": spec,
        "emitter": {'mode': 'all'}},
        core=core
    )
# Out:
# Warning: read_emitter_config() is deprecated and will be removed in a future version. Use use Vivarium for managing simulations and emitters instead of Composite.

# %%
sim2.run(40)

# %%
#gather results
results = sim2.gather_results()[('emitter',)]

# %%
#extract time-series data
timepoints = []
for timepoint in results:
    time = timepoint.pop('global_time')
    timepoints.append(time)
    dfba_spec = timepoint.pop(list(model_dict.keys())[0])
    print(f'TIME: {time}')
    pprint(f'STATE: {timepoint}')
    env = [timepoint['shared environment']['concentrations'] for timepoint in results]
env_combined = {}
for d in env:
    for key, value in d.items():
        if key not in env_combined:
            env_combined[key] = []
        env_combined[key].append(value)
# Out:
# TIME: 0.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': 0, 'Acetate': 0, 'E.coli': "
#  "0}, 'S.flexneri': {'D-Glucose': 0, 'Acetate': 0, 'S.flexneri': 0}}, 'shared "
#  "environment': {'concentrations': {'D-Glucose': 40.0, 'Acetate': 0.0, "
#  "'E.coli': 0.25, 'S.flexneri': 0.25}, 'counts': {'D-Glucose': 80, 'Acetate': "
#  "0, 'E.coli': 0.5, 'S.flexneri': 0.5}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x35ca9c8f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x308522c30>}}')
# TIME: 1.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-7.496251874062968), 'Acetate': np.float64(6.726974615480175), "
#  "'E.coli': np.float64(0.24067371258486692)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-7.496251874062968), 'Acetate': np.float64(6.708871791798614), "
#  "'S.flexneri': np.float64(0.24111451919722585)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': 80, 'Acetate': 0, 'E.coli': 0.5, 'S.flexneri': "
#  "0.5}, 'concentrations': {'D-Glucose': 40.0, 'Acetate': 0.0, 'E.coli': 0.25, "
#  "'S.flexneri': 0.25}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x36a2163f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x177f6fb90>}}')
# TIME: 2.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-11.10397967186553), 'Acetate': np.float64(9.96452735879333), "
#  "'E.coli': np.float64(0.3565057991246457)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-11.11058812519618), 'Acetate': np.float64(9.943628496617135), "
#  "'S.flexneri': np.float64(0.35737102479671384)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(72.50374812593704), 'Acetate': "
#  "np.float64(6.726974615480175), 'E.coli': np.float64(0.7406737125848669), "
#  "'S.flexneri': np.float64(0.7411145191972258)}, 'concentrations': "
#  "{'D-Glucose': np.float64(36.25187406296852), 'Acetate': "
#  "np.float64(3.3634873077400873), 'E.coli': np.float64(0.37033685629243346), "
#  "'S.flexneri': np.float64(0.3705572595986129)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x36a216e70>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x353654a70>}}')
# TIME: 3.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-16.446977991593744), 'Acetate': np.float64(14.759404728819886), "
#  "'E.coli': np.float64(0.5280568948642167)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-16.466555721590556), 'Acetate': np.float64(14.737216825517349), "
#  "'S.flexneri': np.float64(0.5296525083947563)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(61.399768454071506), 'Acetate': "
#  "np.float64(16.691501974273503), 'E.coli': np.float64(1.0971795117095127), "
#  "'S.flexneri': np.float64(1.0984855439939396)}, 'concentrations': "
#  "{'D-Glucose': np.float64(30.699884227035753), 'Acetate': "
#  "np.float64(8.345750987136752), 'E.coli': np.float64(0.5485897558547563), "
#  "'S.flexneri': np.float64(0.5492427719969698)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x36a217950>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x353655910>}}')
# TIME: 4.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-24.35687280753151), 'Acetate': np.float64(21.8582531221857), "
#  "'E.coli': np.float64(0.7820455662864775)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-24.400358799945767), 'Acetate': np.float64(21.83838588039648), "
#  "'S.flexneri': np.float64(0.784871852377929)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(44.952790462477765), 'Acetate': "
#  "np.float64(31.450906703093388), 'E.coli': np.float64(1.6252364065737295), "
#  "'S.flexneri': np.float64(1.628138052388696)}, 'concentrations': "
#  "{'D-Glucose': np.float64(22.476395231238882), 'Acetate': "
#  "np.float64(15.725453351546694), 'E.coli': np.float64(0.8126182032868647), "
#  "'S.flexneri': np.float64(0.814069026194348)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x308520470>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3536567b0>}}')
# TIME: 5.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': "
#  "np.float64(-36.03923662201286), 'Acetate': np.float64(32.345875711409846), "
#  "'E.coli': np.float64(1.1573278589499194)}, 'S.flexneri': {'D-Glucose': "
#  "np.float64(-36.12498905802055), 'Acetate': np.float64(32.33577956873545), "
#  "'S.flexneri': np.float64(1.1621797125135367)}}, 'shared environment': "
#  "{'counts': {'D-Glucose': np.float64(20.595917654946255), 'Acetate': "
#  "np.float64(53.30915982527909), 'E.coli': np.float64(2.407281972860207), "
#  "'S.flexneri': np.float64(2.413009904766625)}, 'concentrations': "
#  "{'D-Glucose': np.float64(10.297958827473128), 'Acetate': "
#  "np.float64(26.654579912639544), 'E.coli': np.float64(1.2036409864301034), "
#  "'S.flexneri': np.float64(1.2065049523833125)}, 'volume': 2}, 'S.flexneri': "
#  "{'inputs': {'shared_environment': ['shared environment'], 'current_update': "
#  "['dFBA Results']}, 'outputs': {'dfba_update': ['dFBA Results', "
#  "'S.flexneri']}, 'interval': 1.0, 'address': 'local:DFBA', 'config': "
#  "{'model_file': 'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': "
#  "(0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': "
#  "'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x308520f50>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x353657650>}}')
# TIME: 6.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.0445307798352905), 'E.coli': np.float64(0.16156987025017774)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-5.961512716681756), 'S.flexneri': "
#  "np.float64(0.11058357850203974)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(85.65503553668893), "
#  "'E.coli': np.float64(3.5646098318101265), 'S.flexneri': "
#  "np.float64(3.5751896172801616)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(42.827517768344464), 'E.coli': "
#  "np.float64(1.7823049159050632), 'S.flexneri': "
#  "np.float64(1.7875948086400808)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x308521af0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x342cdc530>}}')
# TIME: 7.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.363831903317197), 'E.coli': np.float64(0.16889320273379277)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.145907246772372), 'S.flexneri': "
#  "np.float64(0.11400402025273645)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(79.69352282000717), "
#  "'E.coli': np.float64(3.7261797020603042), 'S.flexneri': "
#  "np.float64(3.6857731957822013)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(39.84676141000359), 'E.coli': "
#  "np.float64(1.8630898510301521), 'S.flexneri': "
#  "np.float64(1.8428865978911007)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x308522510>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x342cdd3d0>}}')
# TIME: 8.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.697605702218213), 'E.coli': np.float64(0.17654847333545104)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.336005252540679), 'S.flexneri': "
#  "np.float64(0.11753025910233775)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(72.32969091668998), "
#  "'E.coli': np.float64(3.895072904794097), 'S.flexneri': "
#  "np.float64(3.7997772160349377)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(36.16484545834499), 'E.coli': "
#  "np.float64(1.9475364523970484), 'S.flexneri': "
#  "np.float64(1.8998886080174688)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3085233b0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x342cde270>}}')
# TIME: 9.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.04650816650642), 'E.coli': np.float64(0.18455072751629445)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.531983147208394), 'S.flexneri': "
#  "np.float64(0.12116556744261904)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(65.99368566414931), "
#  "'E.coli': np.float64(4.071621378129548), 'S.flexneri': "
#  "np.float64(3.9173074751372754)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(32.996842832074655), 'E.coli': "
#  "np.float64(2.035810689064774), 'S.flexneri': "
#  "np.float64(1.9586537375686377)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x308523e90>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x342cdf110>}}')
# TIME: 10.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.411225019618323), 'E.coli': np.float64(0.19291569268956402)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.734022800613285), 'S.flexneri': "
#  "np.float64(0.12491331888333977)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(59.46170251694092), "
#  "'E.coli': np.float64(4.256172105645842), 'S.flexneri': "
#  "np.float64(4.038473042579894)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(29.73085125847046), 'E.coli': "
#  "np.float64(2.128086052822921), 'S.flexneri': np.float64(2.019236521289947)}, "
#  "'volume': 2}, 'S.flexneri': {'inputs': {'shared_environment': ['shared "
#  "environment'], 'current_update': ['dFBA Results']}, 'outputs': "
#  "{'dfba_update': ['dFBA Results', 'S.flexneri']}, 'interval': 1.0, 'address': "
#  "'local:DFBA', 'config': {'model_file': 'iSFxv_1172', 'name': 'S.flexneri', "
#  "'kinetics': {'D-Glucose': (0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': "
#  "{'D-Glucose': 'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x177f6c9b0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x342cdffb0>}}')
# TIME: 11.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.79247306616113), 'E.coli': np.float64(0.2016598091308438)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-6.942311707977967), 'S.flexneri': "
#  "np.float64(0.12877699138280582)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(52.72767971632763), "
#  "'E.coli': np.float64(4.449087798335405), 'S.flexneri': "
#  "np.float64(4.163386361463234)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(26.363839858163814), 'E.coli': "
#  "np.float64(2.2245438991677027), 'S.flexneri': "
#  "np.float64(2.081693180731617)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x177f6d4f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3701e4e90>}}')
# TIME: 12.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-9.19100160070107), 'E.coli': np.float64(0.21080026228933246)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.157043163907709), 'S.flexneri': "
#  "np.float64(0.13276017047545646)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(45.785368008349664), "
#  "'E.coli': np.float64(4.650747607466249), 'S.flexneri': "
#  "np.float64(4.292163352846039)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(22.892684004174832), 'E.coli': "
#  "np.float64(2.3253738037331244), 'S.flexneri': "
#  "np.float64(2.1460816764230195)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x177f6df10>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3701e5d30>}}')
# TIME: 13.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-9.607593880406611), 'E.coli': np.float64(0.22035501656365886)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.3784164417701525), 'S.flexneri': "
#  "np.float64(0.13686655259928343)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(36.59436640764859), "
#  "'E.coli': np.float64(4.861547869755581), 'S.flexneri': "
#  "np.float64(4.424923523321495)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(18.297183203824297), 'E.coli': "
#  "np.float64(2.4307739348777906), 'S.flexneri': "
#  "np.float64(2.2124617616607476)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x177f6ea50>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3701e6bd0>}}')
# TIME: 14.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-10.043068664440845), 'E.coli': np.float64(0.23034285060862353)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.606636978623389), 'S.flexneri': "
#  "np.float64(0.1410999485261697)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(29.21594996587844), "
#  "'E.coli': np.float64(5.08190288631924), 'S.flexneri': "
#  "np.float64(4.561790075920778)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(14.60797498293922), 'E.coli': "
#  "np.float64(2.54095144315962), 'S.flexneri': np.float64(2.280895037960389)}, "
#  "'volume': 2}, 'S.flexneri': {'inputs': {'shared_environment': ['shared "
#  "environment'], 'current_update': ['dFBA Results']}, 'outputs': "
#  "{'dfba_update': ['dFBA Results', 'S.flexneri']}, 'interval': 1.0, 'address': "
#  "'local:DFBA', 'config': {'model_file': 'iSFxv_1172', 'name': 'S.flexneri', "
#  "'kinetics': {'D-Glucose': (0.02, 15), 'Acetate': (0.5, 7)}, 'reaction_map': "
#  "{'D-Glucose': 'EX_glc__D_e', 'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x177f6f530>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3701e7a70>}}')
# TIME: 15.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-10.498281823128531), 'E.coli': np.float64(0.24078339424225756)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-7.841916565864014), 'S.flexneri': "
#  "np.float64(0.14546428689833144)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(21.609312987255052), "
#  "'E.coli': np.float64(5.3122457369278635), 'S.flexneri': "
#  "np.float64(4.702890024446948)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(10.804656493627526), 'E.coli': "
#  "np.float64(2.6561228684639318), 'S.flexneri': "
#  "np.float64(2.351445012223474)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x353654410>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x37a34c950>}}')
# TIME: 16.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-10.974128020060405), 'E.coli': np.float64(0.2516971670257341)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.084473545772079), 'S.flexneri': "
#  "np.float64(0.14996361787414528)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(11.111031164126521), "
#  "'E.coli': np.float64(5.553029131170121), 'S.flexneri': "
#  "np.float64(4.848354311345279)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(5.5555155820632605), 'E.coli': "
#  "np.float64(2.7765145655850607), 'S.flexneri': "
#  "np.float64(2.4241771556726395)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3536552b0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x37a34d7f0>}}')
# TIME: 17.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-11.471542470440733), 'E.coli': np.float64(0.2631056185919572)}, "
#  "'S.flexneri': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-8.334533014135356), 'S.flexneri': "
#  "np.float64(0.15460211688674375)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(3.026557618354442), "
#  "'E.coli': np.float64(5.804726298195855), 'S.flexneri': "
#  "np.float64(4.998317929219424)}, 'concentrations': {'D-Glucose': "
#  "np.float64(0.0), 'Acetate': np.float64(1.513278809177221), 'E.coli': "
#  "np.float64(2.9023631490979276), 'S.flexneri': "
#  "np.float64(2.499158964609712)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x353656150>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x37a34e690>}}')
# TIME: 18.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x353656ff0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x37a34f530>}}')
# TIME: 19.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x353657e90>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x384fd8410>}}')
# TIME: 20.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x342cdcd70>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x384fd92b0>}}')
# TIME: 21.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x342cddcd0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x384fda150>}}')
# TIME: 22.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x342cdeab0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x384fdaff0>}}')
# TIME: 23.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x342cdf950>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x384fdbe90>}}')
# TIME: 24.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3701e4830>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x392ae0d70>}}')
# TIME: 25.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3701e56d0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x392ae1c10>}}')
# TIME: 26.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3701e6570>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x392ae2ab0>}}')
# TIME: 27.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x3701e7410>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x392ae3950>}}')
# TIME: 28.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
# ...
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x37a34eed0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x39e08b410>}}')
# TIME: 32.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x37a34fd70>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3a95ec2f0>}}')
# TIME: 33.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x384fd8c50>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3a95ed190>}}')
# TIME: 34.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x384fd9af0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3a95ee030>}}')
# TIME: 35.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x384fda990>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3a95eeed0>}}')
# TIME: 36.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x384fdb830>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3a95efd70>}}')
# TIME: 37.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x392ae0710>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3b7104c50>}}')
# TIME: 38.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x392ae15b0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3b7105af0>}}')
# TIME: 39.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x392ae2450>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3b7106990>}}')
# TIME: 40.0
# ("STATE: {'dFBA Results': {'E.coli': {'D-Glucose': np.float64(0.0), 'Acetate': "
#  "np.float64(-0.9708531066860445), 'E.coli': np.float64(0.0)}, 'S.flexneri': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(-1.2124517755543833), "
#  "'S.flexneri': np.float64(0.0)}}, 'shared environment': {'counts': "
#  "{'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), 'E.coli': "
#  "np.float64(6.067831916787813), 'S.flexneri': np.float64(5.152920046106168)}, "
#  "'concentrations': {'D-Glucose': np.float64(0.0), 'Acetate': np.float64(0.0), "
#  "'E.coli': np.float64(3.0339159583939064), 'S.flexneri': "
#  "np.float64(2.576460023053084)}, 'volume': 2}, 'S.flexneri': {'inputs': "
#  "{'shared_environment': ['shared environment'], 'current_update': ['dFBA "
#  "Results']}, 'outputs': {'dfba_update': ['dFBA Results', 'S.flexneri']}, "
#  "'interval': 1.0, 'address': 'local:DFBA', 'config': {'model_file': "
#  "'iSFxv_1172', 'name': 'S.flexneri', 'kinetics': {'D-Glucose': (0.02, 15), "
#  "'Acetate': (0.5, 7)}, 'reaction_map': {'D-Glucose': 'EX_glc__D_e', "
#  "'Acetate': 'EX_ac_e'}, 'biomass_identifier': "
#  "'BIOMASS_Ec_iJO1366_core_53p95M', 'bounds': {'EX_o2_e': {'lower': -2.0, "
#  "'upper': None}, 'ATPM': {'lower': 1.0, 'upper': 1.0}}}, 'instance': "
#  "<cdFBA.processes.dfba.DFBA object at 0x392ae32f0>}, 'update environment': "
#  "{'inputs': {'species_updates': ['dFBA Results'], 'shared_environment': "
#  "['shared environment']}, 'outputs': {'shared_environment': ['shared "
#  "environment']}, 'interval': 1.0, 'address': 'local:UpdateEnvironment', "
#  "'config': None, 'instance': <cdFBA.processes.dfba.UpdateEnvironment object "
#  'at 0x3b7107830>}}')

# %%
#extract time-series for the shared environment
env = [timepoint['shared environment']['concentrations'] for timepoint in results]
env_combined = {}
for d in env:
    for key, value in d.items():
        if key not in env_combined:
            env_combined[key] = []
        env_combined[key].append(value)

# %%
#plot results for biomass
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key not in ['D-Glucose', 'Acetate']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#plote substrates
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key in ['D-Glucose', 'Acetate']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Injector
# The `Injector` process periodically injects a specific amount of a substrate into the environment. We similarly create a config and add it to specs, injecting 80 D-Glucose every 5 time steps.

# %%
injector_config = {
        "injection_params": {
            "D-Glucose": {
                "amount": 80,
                "interval": 5,
            }
        }
    }
spec3 = deepcopy(spec)
spec3['Injector'] = get_injector_spec(injector_config)

# %%
#Create, run sim, and gather results
sim3 = Composite({
        "state": spec3,
        "emitter": {'mode': 'all'}},
        core=core
    )
sim3.run(40)
results = sim3.gather_results()[('emitter',)]
# Out:
# Warning: read_emitter_config() is deprecated and will be removed in a future version. Use use Vivarium for managing simulations and emitters instead of Composite.

# %%
#extract time-series for the shared environment
env = [timepoint['shared environment']['concentrations'] for timepoint in results]
env_combined = {}
for d in env:
    for key, value in d.items():
        if key not in env_combined:
            env_combined[key] = []
        env_combined[key].append(value)

# %%
#plot results for biomass
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key not in ['D-Glucose', 'Acetate']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#plote substrates
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key in ['D-Glucose']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### WaveFunction
# The `WaveFunction` process dynamically controls the concentration of a substrate based on a wave function, to simulate cyclic patterns of metabolites in the shared environment. This could be analogous to circadian patterns within human bodies or day-night cycle related fluctuations of metabolite availability in the environment.

# %%
wave_config = {
    "substrate_params": {
        "D-Glucose": {
            "amplitude": 5,
            "angular_frequency": 1,
            "base_concentration": 40,
            "phase_shift": 0
        }
    }
}
spec4 = deepcopy(spec)
spec4['Wave Function'] = get_wave_spec(wave_config)

# %%
#Create, run sim, and gather results
sim4 = Composite({
        "state": spec4,
        "emitter": {'mode': 'all'}},
        core=core
    )
sim4.run(40)
results = sim4.gather_results()[('emitter',)]
# Out:
# Warning: read_emitter_config() is deprecated and will be removed in a future version. Use use Vivarium for managing simulations and emitters instead of Composite.

# %%
#extract time-series for the shared environment
env = [timepoint['shared environment']['concentrations'] for timepoint in results]
env_combined = {}
for d in env:
    for key, value in d.items():
        if key not in env_combined:
            env_combined[key] = []
        env_combined[key].append(value)

# %%
#plot results for biomass
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key not in ['D-Glucose', 'Acetate']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#plote substrates
fig, ax = plt.subplots(dpi=100)
for key, value in env_combined.items():
    if key in ['D-Glucose']:
        ax.plot(timepoints, env_combined[key], label=key)
plt.xlabel('Time')
plt.ylabel('Substrate Concentration')
plt.legend()
plt.tight_layout()
plt.show()
